# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
X = pd.read_csv('challenge_data/X_train.csv')
y = pd.read_csv('challenge_data/y_train.csv')

# %%
null_counts = X.isnull().sum()
print("Null Values in Each Column:")
print(null_counts)
# Out:
# Null Values in Each Column:
# ID                    0
# DAY_ID                0
# COUNTRY               0
# DE_CONSUMPTION        0
# FR_CONSUMPTION        0
# DE_FR_EXCHANGE       25
# FR_DE_EXCHANGE       25
# DE_NET_EXPORT       124
# FR_NET_EXPORT        70
# DE_NET_IMPORT       124
# FR_NET_IMPORT        70
# DE_GAS                0
# FR_GAS                0
# DE_COAL               0
# FR_COAL               0
# DE_HYDRO              0
# FR_HYDRO              0
# DE_NUCLEAR            0
# FR_NUCLEAR            0
# DE_SOLAR              0
# FR_SOLAR              0
# DE_WINDPOW            0
# FR_WINDPOW            0
# DE_LIGNITE            0
# DE_RESIDUAL_LOAD      0
# FR_RESIDUAL_LOAD      0
# DE_RAIN              94
# FR_RAIN              94
# DE_WIND              94
# FR_WIND              94
# DE_TEMP              94
# FR_TEMP              94
# GAS_RET               0
# COAL_RET              0
# CARBON_RET            0
# dtype: int64

# %%
y
# Out:
#         ID    TARGET
# 0     1054  0.028313
# 1     2049 -0.112516
# 2     1924 -0.180840
# 3      297 -0.260356
# 4     1101 -0.071733
# ...    ...       ...
# 1489   459 -0.172597
# 1490  1674 -0.063546
# 1491   748  0.151797
# 1492  1454 -0.640917
# 1493   359 -0.252764
#
# [1494 rows x 2 columns]

# %%
X = X.sort_values("DAY_ID")

# %%
de = X[X['COUNTRY'] == 'DE']

# %%
fr = X[X['COUNTRY'] == 'FR']
fr_plot = fr[:200]
fr[fr['DE_FR_EXCHANGE'].isnull()]
# Out:
#        ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 61    936      28      FR        1.408520        1.391108             NaN
# 39    935      52      FR        1.231695        1.269656             NaN
# 468   951      58      FR        1.472340        2.439284             NaN
# 1357  937      65      FR        1.075988        1.276328             NaN
# 1320  956      75      FR        1.383749        2.236917             NaN
# 299   958     126      FR        1.203701        1.399900             NaN
# 1087  957     157      FR        1.664367        1.665369             NaN
# 877   952     159      FR        1.445497        2.447421             NaN
# 459   953     186      FR        1.418318        2.410895             NaN
# 1050  965     212      FR        1.840984        3.079180             NaN
# 754   946     308      FR        1.542430        1.293023             NaN
# 1367  961     322      FR        1.223828        1.816612             NaN
# 1272  950     354      FR        1.330637        2.313961             NaN
# 1245  944     594      FR        1.244455        1.140339             NaN
# 337   934     740      FR        0.683673        0.813651             NaN
# 152   959     744      FR        1.099693        1.570898             NaN
# 1174  940     802      FR        1.489934        1.576587             NaN
# 19    964     804      FR        1.585749        2.632105             NaN
# 401   938     874      FR        1.130684        1.382883             NaN
# 909   947     902      FR        1.480108        1.546767             NaN
# 864   945     927      FR        1.322486        1.171245             NaN
# 1204  933     992      FR        0.880508        0.881603             NaN
# 64    955    1069      FR        1.196808        2.342962             NaN
# 1445  942    1141      FR        1.244486        1.068779             NaN
# 923   963    1171      FR        1.250809        2.219071             NaN
#
#       FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 61               NaN            NaN            NaN            NaN  ...
# 39               NaN            NaN            NaN            NaN  ...
# 468              NaN            NaN            NaN            NaN  ...
# 1357             NaN            NaN            NaN            NaN  ...
# 1320             NaN            NaN            NaN            NaN  ...
# 299              NaN            NaN            NaN            NaN  ...
# 1087             NaN            NaN            NaN            NaN  ...
# 877              NaN            NaN            NaN            NaN  ...
# 459              NaN            NaN            NaN            NaN  ...
# 1050             NaN            NaN            NaN            NaN  ...
# 754              NaN            NaN            NaN            NaN  ...
# 1367             NaN            NaN            NaN            NaN  ...
# 1272             NaN            NaN            NaN            NaN  ...
# 1245             NaN            NaN            NaN            NaN  ...
# 337              NaN            NaN            NaN            NaN  ...
# 152              NaN            NaN            NaN            NaN  ...
# 1174             NaN            NaN            NaN            NaN  ...
# 19               NaN            NaN            NaN            NaN  ...
# 401              NaN            NaN            NaN            NaN  ...
# 909              NaN            NaN            NaN            NaN  ...
# 864              NaN            NaN            NaN            NaN  ...
# 1204             NaN            NaN            NaN            NaN  ...
# 64               NaN            NaN            NaN            NaN  ...
# 1445             NaN            NaN            NaN            NaN  ...
# 923              NaN            NaN            NaN            NaN  ...
#
#       FR_RESIDUAL_LOAD   DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP  \
# 61            1.486483 -0.967634  0.555446 -0.510427 -0.985396 -0.885387
# 39            1.264296 -1.228214  0.962364 -0.462356 -0.364924 -1.044338
# 468           2.523329 -0.155963  0.868849 -1.222456 -0.659191 -1.486098
# 1357          1.391707 -0.679139  0.036572 -1.324837 -0.784565 -0.282143
# 1320          2.129408 -0.318578 -0.066699 -0.709662 -0.546329 -1.086671
# 299           1.585094  0.918051  0.167931 -0.673886 -1.034774 -0.688666
# 1087          1.642085  0.457497  1.832659 -0.383511 -0.917849 -1.458492
# 877           2.646770 -0.073815 -0.322790 -1.538436 -1.355023 -1.679708
# 459           2.344515 -0.387011  0.113151 -1.306267 -1.157183 -1.562302
# 1050          2.918326 -0.321000 -0.846733 -0.528320 -0.454867 -3.998837
# 754           0.944127  0.999125  1.353887 -0.193455 -0.116736  1.137102
# 1367          1.612516 -0.829865 -0.374158 -1.115790 -0.027285 -1.499644
# 1272          2.372387 -0.389086  1.597882 -1.052459 -0.642847 -1.419704
# 1245          1.122885  0.508716 -0.572415  0.211397 -1.119313  1.899040
# 337           0.702082  0.979414  0.967726 -0.365213 -0.608444  1.465248
# 152           1.784915 -0.519663 -0.243607 -1.214872 -0.974921 -1.090623
# 1174          1.193379 -0.134913  1.141601 -0.124698 -0.298330 -0.584097
# 19            2.122268 -0.257192 -0.311929 -0.346666  0.450660 -3.494385
# 401           1.590333  0.119506 -0.170922 -1.506387 -0.851370 -0.133840
# 909           1.506125  0.914104 -0.121676 -0.500129 -0.830899  0.510557
# 864           1.377146 -0.208264 -0.687081 -0.575771 -1.076987  1.188873
# 1204          0.427023  2.034344  2.127580 -0.205264  0.123975  1.075974
# 64            2.115911 -0.227825 -0.208872 -0.754866 -0.729064 -0.442171
# 1445          1.097148  0.593125  0.932309 -0.444571 -0.067636  2.588654
# 923           1.987046 -1.198854 -0.471321 -0.797397 -0.292917 -1.945030
#
#        FR_TEMP   GAS_RET  COAL_RET  CARBON_RET
# 61   -0.298126 -0.236740  0.616277    0.787153
# 39    0.456897  0.078996 -0.606772    0.270359
# 468  -1.936584  0.223220  0.849366    0.879215
# 1357  0.513167 -0.435396  0.556208    0.131572
# 1320 -1.332688  0.226180 -1.192092   -0.332399
# 299  -0.258374  0.318572 -0.082472    0.935613
# 1087  0.110873 -0.676501 -0.245869   -0.807220
# 877  -1.693058 -2.492647  0.568863   -0.772683
# 459  -1.963222 -1.749550  0.474484    0.006498
# 1050 -3.964949 -1.255258  2.124227    0.260547
# 754   0.780850 -1.292467  1.772029    1.475126
# 1367 -1.451368 -0.433795 -0.647556   -0.159835
# 1272 -1.328871 -1.658968 -1.171063    0.512507
# 1245  0.979937 -1.380725 -0.389496   -0.686429
# 337   1.605309  0.317321  0.050629   -0.551201
# 152  -1.004536  2.129942  1.487611    2.080541
# 1174  0.143271 -0.357743 -0.300298   -1.325776
# 19   -3.217619 -2.846590 -0.721817   -1.424329
# 401   0.128882 -0.199062 -0.349016   -0.357618
# 909  -0.296548 -1.484809 -0.042391    0.647896
# 864   0.955688 -0.579190 -0.524521   -0.282637
# 1204  1.835761 -0.355296 -0.301449   -0.220830
# 64   -1.361997  2.524928  1.742869    0.766463
# 1445  1.617986  0.000000 -0.914862   -0.175794
# 923  -2.285661 -0.257892  0.364250   -3.610462
#
# [25 rows x 35 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(fr_plot['DAY_ID'], fr_plot['DE_FR_EXCHANGE'], linestyle='-', color='skyblue')
plt.xlabel('DAY_ID')
plt.ylabel('DE_FR_EXCHANGE')
plt.title('DE_FR_EXCHANGE for COUNTRY = FR')
plt.savefig('images/fr_exchange_null.png')
plt.show()

# %%
fr[fr['FR_NET_EXPORT'].isnull()]
# Out:
#         ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 61     936      28      FR        1.408520        1.391108             NaN
# 614   1021      29      FR        0.530319       -0.566085       -0.555051
# 1375   993      50      FR        0.511014        0.069335        0.918642
# 39     935      52      FR        1.231695        1.269656             NaN
# 468    951      58      FR        1.472340        2.439284             NaN
# ...    ...     ...     ...             ...             ...             ...
# 1230   990    1153      FR        0.860181        0.470422        0.671038
# 923    963    1171      FR        1.250809        2.219071             NaN
# 331    969    1173      FR        0.759177        1.259905        1.454368
# 537   1018    1186      FR       -1.790916       -1.161327       -0.490623
# 1451   972    1209      FR        1.109804        1.301061        1.565552
#
#       FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 61               NaN            NaN            NaN            NaN  ...
# 614         0.555051            NaN            NaN            NaN  ...
# 1375       -0.918642            NaN            NaN            NaN  ...
# 39               NaN            NaN            NaN            NaN  ...
# 468              NaN            NaN            NaN            NaN  ...
# ...              ...            ...            ...            ...  ...
# 1230       -0.671038            NaN            NaN            NaN  ...
# 923              NaN            NaN            NaN            NaN  ...
# 331        -1.454368            NaN            NaN            NaN  ...
# 537         0.490623            NaN            NaN            NaN  ...
# 1451       -1.565552            NaN            NaN            NaN  ...
#
#       FR_RESIDUAL_LOAD   DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP  \
# 61            1.486483 -0.967634  0.555446 -0.510427 -0.985396 -0.885387
# 614          -0.370090  0.214589  0.012755 -0.530967 -1.030422  0.804944
# 1375          0.223836  2.363869  0.017478 -0.863228 -0.627465  0.990850
# 39            1.264296 -1.228214  0.962364 -0.462356 -0.364924 -1.044338
# 468           2.523329 -0.155963  0.868849 -1.222456 -0.659191 -1.486098
# ...                ...       ...       ...       ...       ...       ...
# 1230          0.358199  1.221839  0.209827  0.087945 -0.666912  0.449077
# 923           1.987046 -1.198854 -0.471321 -0.797397 -0.292917 -1.945030
# 331           1.270345  0.002752 -0.626431 -0.807145 -1.209736 -0.809211
# 537          -1.009067 -0.647874 -0.900898 -0.320731 -1.100227  0.094048
# 1451          1.038585  0.457145 -0.202629 -0.395438 -0.463636 -0.251075
#
#        FR_TEMP   GAS_RET  COAL_RET  CARBON_RET
# 61   -0.298126 -0.236740  0.616277    0.787153
# 614   0.611515  0.121422  0.689455   -0.021530
# 1375  0.211675 -0.046202  1.012198    0.810468
# 39    0.456897  0.078996 -0.606772    0.270359
# 468  -1.936584  0.223220  0.849366    0.879215
# ...        ...       ...       ...         ...
# 1230 -0.224944  0.797473 -1.223072   -0.084172
# 923  -2.285661 -0.257892  0.364250   -3.610462
# 331   0.349555  1.549771  0.853510   -0.832626
# 537   0.198600  0.482342  0.786913    0.528879
# 1451 -0.387127 -0.411589  1.774694    1.038661
#
# [70 rows x 35 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(fr_plot['DAY_ID'], fr_plot['FR_NET_EXPORT'], linestyle='-', color='skyblue')
plt.xlabel('DAY_ID')
plt.ylabel('FR_NET_EXPORT')
plt.title('FR_NET_EXPORT')
plt.savefig('images/fr_export_null.png')
plt.show()

# %%
fr[fr['FR_NET_IMPORT'].isnull()]
# Out:
#         ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 61     936      28      FR        1.408520        1.391108             NaN
# 614   1021      29      FR        0.530319       -0.566085       -0.555051
# 1375   993      50      FR        0.511014        0.069335        0.918642
# 39     935      52      FR        1.231695        1.269656             NaN
# 468    951      58      FR        1.472340        2.439284             NaN
# ...    ...     ...     ...             ...             ...             ...
# 1230   990    1153      FR        0.860181        0.470422        0.671038
# 923    963    1171      FR        1.250809        2.219071             NaN
# 331    969    1173      FR        0.759177        1.259905        1.454368
# 537   1018    1186      FR       -1.790916       -1.161327       -0.490623
# 1451   972    1209      FR        1.109804        1.301061        1.565552
#
#       FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 61               NaN            NaN            NaN            NaN  ...
# 614         0.555051            NaN            NaN            NaN  ...
# 1375       -0.918642            NaN            NaN            NaN  ...
# 39               NaN            NaN            NaN            NaN  ...
# 468              NaN            NaN            NaN            NaN  ...
# ...              ...            ...            ...            ...  ...
# 1230       -0.671038            NaN            NaN            NaN  ...
# 923              NaN            NaN            NaN            NaN  ...
# 331        -1.454368            NaN            NaN            NaN  ...
# 537         0.490623            NaN            NaN            NaN  ...
# 1451       -1.565552            NaN            NaN            NaN  ...
#
#       FR_RESIDUAL_LOAD   DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP  \
# 61            1.486483 -0.967634  0.555446 -0.510427 -0.985396 -0.885387
# 614          -0.370090  0.214589  0.012755 -0.530967 -1.030422  0.804944
# 1375          0.223836  2.363869  0.017478 -0.863228 -0.627465  0.990850
# 39            1.264296 -1.228214  0.962364 -0.462356 -0.364924 -1.044338
# 468           2.523329 -0.155963  0.868849 -1.222456 -0.659191 -1.486098
# ...                ...       ...       ...       ...       ...       ...
# 1230          0.358199  1.221839  0.209827  0.087945 -0.666912  0.449077
# 923           1.987046 -1.198854 -0.471321 -0.797397 -0.292917 -1.945030
# 331           1.270345  0.002752 -0.626431 -0.807145 -1.209736 -0.809211
# 537          -1.009067 -0.647874 -0.900898 -0.320731 -1.100227  0.094048
# 1451          1.038585  0.457145 -0.202629 -0.395438 -0.463636 -0.251075
#
#        FR_TEMP   GAS_RET  COAL_RET  CARBON_RET
# 61   -0.298126 -0.236740  0.616277    0.787153
# 614   0.611515  0.121422  0.689455   -0.021530
# 1375  0.211675 -0.046202  1.012198    0.810468
# 39    0.456897  0.078996 -0.606772    0.270359
# 468  -1.936584  0.223220  0.849366    0.879215
# ...        ...       ...       ...         ...
# 1230 -0.224944  0.797473 -1.223072   -0.084172
# 923  -2.285661 -0.257892  0.364250   -3.610462
# 331   0.349555  1.549771  0.853510   -0.832626
# 537   0.198600  0.482342  0.786913    0.528879
# 1451 -0.387127 -0.411589  1.774694    1.038661
#
# [70 rows x 35 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(fr_plot['DAY_ID'], fr_plot['FR_NET_IMPORT'], linestyle='-', color='skyblue')
plt.xlabel('DAY_ID')
plt.ylabel('FR_NET_IMPORT')
plt.title('FR_NET_IMPORT')
plt.savefig('images/fr_import_null.png')
plt.show()

# %%
fr[fr['FR_RAIN'].isnull()]
# Out:
#         ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 101   1712      11      FR        0.960072        0.893360        0.572874
# 26    1715      27      FR        0.710437        0.302015        0.010281
# 1138  1686      73      FR        1.650742        2.291531       -0.172069
# 758   1706      74      FR        1.287193        0.555468        0.223346
# 393   1696      96      FR        0.809707        0.286354       -0.569527
# 478   1703      98      FR        1.163739        0.993851        0.014411
# 59    1709     130      FR        1.066915        0.807366       -2.039503
# 534   1681     155      FR        1.094086        0.682399       -0.652040
# 144   1694     253      FR        0.903682        0.117425       -1.682975
# 624   1671     262      FR        1.336711        1.260471        0.814849
# 1218  1697     278      FR        0.770010        0.544477       -0.110815
# 1011  1673     282      FR        1.601189        2.083674        1.509189
# 170   1672     304      FR        1.256611        1.785053       -0.649171
# 929   1722     330      FR        1.390092        0.734470        0.617978
# 1026  1678     336      FR        1.373335        0.775003       -2.438266
# 1310  1701     345      FR        0.917309        0.671345       -0.482189
# 532   1714     355      FR        0.887536        0.458947        0.187241
# 1388  1667     387      FR        1.487760        1.804164        1.296168
# 772   1719     424      FR        0.250075       -0.388972       -1.432524
# 1309  1689     497      FR        1.428743        0.934636       -0.449670
# 1189  1704     500      FR        1.185957        0.943133        0.154266
# 1112  1713     535      FR        1.028187        0.718891        0.148006
# 969   1705     538      FR        1.600702        0.577669        0.057385
# 645   1685     557      FR        1.791654        2.244959       -0.624609
# 949   1723     561      FR        1.060201        0.540495        0.812675
# 1117  1698     677      FR        0.824106        0.546982        0.425411
# 981   1665     678      FR        1.605983        1.459767       -0.448453
# 674   1692     679      FR        0.689256        0.400673       -1.102776
# 876   1660     689      FR        1.058364        2.335423        1.976357
# 33    1659     725      FR        0.621926        2.261159        1.743034
# 1158  1669     739      FR        1.689605        1.451348        0.930532
# 690   1676     767      FR        1.285364        0.782861       -1.027784
# 502   1658     775      FR        1.021339        2.237380        2.495411
# 1441  1680     783      FR        1.184358        0.875160        0.073427
# 45    1675     809      FR        1.529204        1.106682       -1.855327
# 389   1718     815      FR        0.480992       -0.288113       -0.717794
# 675   1690     832      FR        1.296901        0.973266       -0.653258
# 1065  1684     859      FR        1.846347        2.023218       -0.171221
# 1490  1674     887      FR        1.618582        1.752840        0.611392
# 1179  1716     957      FR        0.527603        0.228393       -0.348312
# 677   1710    1011      FR        1.048916        1.003699       -1.580595
# 413   1693    1037      FR        0.858570        0.214094       -1.473715
# 1039  1682    1044      FR        1.532885        1.621742        1.226545
# 791   1695    1052      FR        0.792260        0.187043       -0.792134
# 979   1662    1111      FR        1.759370        2.432090        1.130185
# 372   1721    1207      FR        1.002463        0.516789        0.651648
# 873   1688    1213      FR        1.407027        1.313254       -0.456126
#
#       FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 101        -0.572874      -0.431157      -0.681410       0.431157  ...
# 26         -0.010281      -0.574293       0.197104       0.574293  ...
# 1138        0.172069      -0.061632      -0.821459       0.061632  ...
# 758        -0.223346       1.486049       0.286253      -1.486049  ...
# 393         0.569527      -0.858605       0.293767       0.858605  ...
# 478        -0.014411      -0.247227      -0.636112       0.247227  ...
# 59          2.039503      -1.618459       0.696194       1.618459  ...
# 534         0.652040       0.210913       0.784182      -0.210913  ...
# 144         1.682975      -0.414103       0.376951       0.414103  ...
# 624        -0.814849       0.875276      -0.182089      -0.875276  ...
# 1218        0.110815      -1.130959      -0.311867       1.130959  ...
# 1011       -1.509189       0.567914      -0.378055      -0.567914  ...
# 170         0.649171      -0.729855       0.041500       0.729855  ...
# 929        -0.617978       0.397707      -1.484740      -0.397707  ...
# 1026        2.438266      -0.648085       1.340263       0.648085  ...
# 1310        0.482189      -0.837953       0.296002       0.837953  ...
# 532        -0.187241      -0.306899      -0.132897       0.306899  ...
# 1388       -1.296168       1.137145      -0.187391      -1.137145  ...
# 772         1.432524      -1.699539       0.676002       1.699539  ...
# 1309        0.449670       0.583453       0.140900      -0.583453  ...
# 1189       -0.154266      -0.212713      -0.133933       0.212713  ...
# 1112       -0.148006      -0.864829      -0.461389       0.864829  ...
# 969        -0.057385       0.993229       0.268780      -0.993229  ...
# 645         0.624609      -1.121310      -0.891157       1.121310  ...
# 949        -0.812675       0.273313      -1.797193      -0.273313  ...
# 1117       -0.425411      -0.735744      -0.300474       0.735744  ...
# 981         0.448453      -0.244380       0.662073       0.244380  ...
# 674         1.102776      -0.743703       0.595829       0.743703  ...
# 876        -1.976357      -0.214021      -1.570298       0.214021  ...
# 33         -1.743034       0.267362      -1.691992      -0.267362  ...
# 1158       -0.930532       1.427424       0.342051      -1.427424  ...
# 690         1.027784       0.806367       1.247250      -0.806367  ...
# 502        -2.495411       1.134751      -1.616863      -1.134751  ...
# 1441       -0.073427       0.017004       0.707812      -0.017004  ...
# 45          1.855327      -0.218658       1.450426       0.218658  ...
# 389         0.717794      -1.139514       0.450894       1.139514  ...
# 675         0.653258       0.371682       0.275098      -0.371682  ...
# 1065        0.171221      -0.244606      -0.706006       0.244606  ...
# 1490       -0.611392       0.449153      -0.152146      -0.449153  ...
# 1179        0.348312      -0.347925       0.505116       0.347925  ...
# 677         1.580595      -1.545274       0.178805       1.545274  ...
# 413         1.473715      -0.725901       0.572277       0.725901  ...
# 1039       -1.226545       0.966391      -0.841198      -0.966391  ...
# 791         0.792134      -0.578454       0.424857       0.578454  ...
# 979        -1.130185       0.946258      -1.120062      -0.946258  ...
# 372        -0.651648       0.728817      -0.820640      -0.728817  ...
# 873         0.456126       0.333142      -0.069222      -0.333142  ...
#
#       FR_RESIDUAL_LOAD  DE_RAIN  FR_RAIN  DE_WIND  FR_WIND  DE_TEMP  FR_TEMP  \
# 101           0.802531      NaN      NaN      NaN      NaN      NaN      NaN
# 26            0.373842      NaN      NaN      NaN      NaN      NaN      NaN
# 1138          1.914886      NaN      NaN      NaN      NaN      NaN      NaN
# 758          -0.201348      NaN      NaN      NaN      NaN      NaN      NaN
# 393           0.278825      NaN      NaN      NaN      NaN      NaN      NaN
# 478           1.024856      NaN      NaN      NaN      NaN      NaN      NaN
# 59            0.379480      NaN      NaN      NaN      NaN      NaN      NaN
# 534           0.827539      NaN      NaN      NaN      NaN      NaN      NaN
# 144          -0.176061      NaN      NaN      NaN      NaN      NaN      NaN
# 624           1.175926      NaN      NaN      NaN      NaN      NaN      NaN
# 1218          0.431351      NaN      NaN      NaN      NaN      NaN      NaN
# 1011          1.979464      NaN      NaN      NaN      NaN      NaN      NaN
# 170           1.704706      NaN      NaN      NaN      NaN      NaN      NaN
# 929           0.528487      NaN      NaN      NaN      NaN      NaN      NaN
# 1026          0.281694      NaN      NaN      NaN      NaN      NaN      NaN
# 1310          0.496088      NaN      NaN      NaN      NaN      NaN      NaN
# 532           0.487575      NaN      NaN      NaN      NaN      NaN      NaN
# 1388          1.742892      NaN      NaN      NaN      NaN      NaN      NaN
# 772          -0.351462      NaN      NaN      NaN      NaN      NaN      NaN
# 1309          0.555635      NaN      NaN      NaN      NaN      NaN      NaN
# 1189          0.510252      NaN      NaN      NaN      NaN      NaN      NaN
# 1112          0.757372      NaN      NaN      NaN      NaN      NaN      NaN
# 969          -0.303210      NaN      NaN      NaN      NaN      NaN      NaN
# 645           1.995261      NaN      NaN      NaN      NaN      NaN      NaN
# 949           0.576414      NaN      NaN      NaN      NaN      NaN      NaN
# 1117          0.566401      NaN      NaN      NaN      NaN      NaN      NaN
# 981           1.048016      NaN      NaN      NaN      NaN      NaN      NaN
# 674           0.300459      NaN      NaN      NaN      NaN      NaN      NaN
# 876           2.537454      NaN      NaN      NaN      NaN      NaN      NaN
# 33            2.475473      NaN      NaN      NaN      NaN      NaN      NaN
# 1158          0.667220      NaN      NaN      NaN      NaN      NaN      NaN
# 690           0.039585      NaN      NaN      NaN      NaN      NaN      NaN
# 502           2.392852      NaN      NaN      NaN      NaN      NaN      NaN
# 1441          0.929860      NaN      NaN      NaN      NaN      NaN      NaN
# 45            0.509514      NaN      NaN      NaN      NaN      NaN      NaN
# 389          -0.291661      NaN      NaN      NaN      NaN      NaN      NaN
# 675           0.542037      NaN      NaN      NaN      NaN      NaN      NaN
# 1065          1.784674      NaN      NaN      NaN      NaN      NaN      NaN
# 1490          1.666252      NaN      NaN      NaN      NaN      NaN      NaN
# 1179         -0.058177      NaN      NaN      NaN      NaN      NaN      NaN
# 677           0.960358      NaN      NaN      NaN      NaN      NaN      NaN
# 413          -0.160909      NaN      NaN      NaN      NaN      NaN      NaN
# 1039          1.798654      NaN      NaN      NaN      NaN      NaN      NaN
# 791           0.192108      NaN      NaN      NaN      NaN      NaN      NaN
# 979           2.343126      NaN      NaN      NaN      NaN      NaN      NaN
# 372           0.236243      NaN      NaN      NaN      NaN      NaN      NaN
# 873           0.868310      NaN      NaN      NaN      NaN      NaN      NaN
#
#        GAS_RET  COAL_RET  CARBON_RET
# 101   1.497554  0.885105    0.906909
# 26    0.065680 -1.250163   -0.240992
# 1138 -0.235566  1.240369    0.289073
# 758   0.631231  0.920510    0.354582
# 393   0.412395 -1.061074   -0.166493
# 478   0.929566  1.628401    0.964213
# 59    1.573358  1.414529    0.356393
# 534   1.026604  0.940184    0.307300
# 144   0.274211  0.508566    0.186006
# 624   0.432061  0.149860    1.523092
# 1218  0.000000 -0.166544    0.497237
# 1011  0.692620  0.231002   -1.343067
# 170  -0.214028 -1.234383   -1.364511
# 929  -1.015696 -0.360308   -0.507452
# 1026 -0.214745  2.523408    0.132231
# 1310 -0.759066  0.933737    0.550033
# 532   0.297234  0.172894    0.218442
# 1388 -1.469110 -0.141242   -1.272137
# 772  -0.033090  0.496947    0.394239
# 1309 -0.380672 -0.752106   -0.212513
# 1189  0.561596  0.918244    0.837702
# 1112 -0.536211 -1.385699    0.384377
# 969   0.034673  0.394093    0.562209
# 645  -0.890944 -0.550139   -1.307543
# 949  -1.327917 -0.362709   -0.311724
# 1117  0.653942  1.350682   -0.266867
# 981  -0.539853 -0.133094   -0.173480
# 674  -0.508466  0.586330   -0.719391
# 876   2.590490  1.186364    2.946484
# 33   -0.429607  0.721945   -0.766894
# 1158  0.212583 -0.210857   -0.071389
# 690  -0.583988 -1.190652   -0.620363
# 502  -4.269256 -0.770407   -2.868455
# 1441  0.981584 -0.160754    0.319083
# 45    0.876984  0.819520    1.320373
# 389  -0.328509  0.199400    0.359000
# 675   0.771316  0.232567    0.963497
# 1065 -0.782840  1.063022   -0.529539
# 1490  0.932633 -0.085690    0.356356
# 1179  0.426205  1.412624    0.085717
# 677   0.099215 -0.580000   -0.235506
# 413   0.137544  0.766558    0.189035
# 1039  1.604863  0.407203    2.049339
# 791   0.136476 -0.946898   -0.536382
# 979  -0.296080 -0.399210    2.841211
# 372   0.099209  1.750872    0.646905
# 873  -0.103642 -0.633007    0.214805
#
# [47 rows x 35 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(fr_plot['DAY_ID'], fr_plot['FR_RAIN'], linestyle='-', color='skyblue')
plt.xlabel('DAY_ID')
plt.ylabel('FR_RAIN')
plt.title('FR_RAIN')
plt.savefig('images/fr_rain_null.png')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(fr_plot['DAY_ID'], fr_plot['FR_WIND'], linestyle='-', color='skyblue')
plt.xlabel('DAY_ID')
plt.ylabel('FR_WIND')
plt.title('FR_WIND')
plt.savefig('images/fr_wind_null.png')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(fr_plot['DAY_ID'], fr_plot['FR_TEMP'], linestyle='-', color='skyblue')
plt.xlabel('DAY_ID')
plt.ylabel('FR_TEMP')
plt.title('FR_TEMP')
plt.savefig('images/fr_temp_null.png')
plt.show()

# %%
def fill_missing_with_average(df):
    # Iterate over each column in the DataFrame
    for col in df.columns:
        # Iterate over each row in the column
        for i in range(len(df[col])):
            # Check if the value is missing
            if pd.isnull(df.iloc[i][col]):
                # Find the nearest non-missing value by moving backward
                j = i - 1
                while j >= 0 and pd.isnull(df.iloc[j][col]):
                    j -= 1
                
                # Find the nearest non-missing value by moving forward
                k = i + 1
                while k < len(df[col]) and pd.isnull(df.iloc[k][col]):
                    k += 1

                # Calculate the average of the nearest non-missing values
                if j >= 0 and k < len(df[col]):
                    average_value = (df.iloc[j][col] + df.iloc[k][col]) / 2
                elif j >= 0:
                    average_value = df.iloc[j][col]
                elif k < len(df[col]):
                    average_value = df.iloc[k][col]
                else:
                    # If no non-missing values are found, set to 0 (or any default value)
                    average_value = 0
                
                # Fill the missing value with the calculated average
                df.iloc[i, df.columns.get_loc(col)] = average_value
    
    return df

# %%
fr_filled = fill_missing_with_average(fr)

# %%
null_counts = fr_filled.isnull().sum()
print("Null Values in Each Column:")
print(null_counts)
# Out:
# Null Values in Each Column:
# ID                  0
# DAY_ID              0
# COUNTRY             0
# DE_CONSUMPTION      0
# FR_CONSUMPTION      0
# DE_FR_EXCHANGE      0
# FR_DE_EXCHANGE      0
# DE_NET_EXPORT       0
# FR_NET_EXPORT       0
# DE_NET_IMPORT       0
# FR_NET_IMPORT       0
# DE_GAS              0
# FR_GAS              0
# DE_COAL             0
# FR_COAL             0
# DE_HYDRO            0
# FR_HYDRO            0
# DE_NUCLEAR          0
# FR_NUCLEAR          0
# DE_SOLAR            0
# FR_SOLAR            0
# DE_WINDPOW          0
# FR_WINDPOW          0
# DE_LIGNITE          0
# DE_RESIDUAL_LOAD    0
# FR_RESIDUAL_LOAD    0
# DE_RAIN             0
# FR_RAIN             0
# DE_WIND             0
# FR_WIND             0
# DE_TEMP             0
# FR_TEMP             0
# GAS_RET             0
# COAL_RET            0
# CARBON_RET          0
# dtype: int64

# %%
fr_fill_plot = fr_filled[:200]

# %%
plt.figure(figsize=(12, 6))
plt.plot(fr_fill_plot['DAY_ID'], fr_fill_plot['FR_TEMP'], linestyle='-', color='skyblue')
plt.xlabel('DAY_ID')
plt.ylabel('FR_TEMP')
plt.title('FR_TEMP_FILL_NA')
plt.savefig('images/fr_temp.png')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(fr_fill_plot['DAY_ID'], fr_fill_plot['FR_NET_IMPORT'], linestyle='-', color='skyblue')
plt.xlabel('DAY_ID')
plt.ylabel('FR_NET_IMPORT')
plt.title('FR_NET_IMPORT_FILL_NA')
plt.savefig('images/fr_net_import.png')
plt.show()

# %%
fr
# Out:
#         ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 742   1057       0      FR        0.048418       -0.465067       -0.079296
# 1211  1179       1      FR        0.966997        1.222131        0.331356
# 1408  1327       2      FR       -0.068972       -0.667390       -1.102015
# 329   2016       3      FR       -0.134670       -0.834564       -1.051716
# 512   2047       5      FR       -0.297850       -0.470371        0.144615
# ...    ...     ...     ...             ...             ...             ...
# 479   2039    1208      FR        0.046568       -0.709011        0.427976
# 1451   972    1209      FR        1.109804        1.301061        1.565552
# 1007  1987    1212      FR       -0.046100       -0.520506       -0.270515
# 873   1688    1213      FR        1.407027        1.313254       -0.456126
# 1437  1049    1215      FR        0.544810       -0.378158       -0.065993
#
#       FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 742         0.079296       0.405549       0.650577      -0.405549  ...
# 1211       -0.331356       0.405549       0.778627      -0.405549  ...
# 1408        1.102015      -1.080403       0.256736       1.080403  ...
# 329         1.051716      -1.881881      -0.612133       1.881881  ...
# 512        -0.144615      -1.208286      -1.811403       1.208286  ...
# ...              ...            ...            ...            ...  ...
# 479        -0.427976      -0.578391      -1.678101       0.578391  ...
# 1451       -1.565552      -0.358154      -1.233963       0.358154  ...
# 1007        0.270515      -0.137917      -0.789824       0.137917  ...
# 873         0.456126       0.333142      -0.069222      -0.333142  ...
# 1437        0.065993       0.333142       0.257829      -0.333142  ...
#
#       FR_RESIDUAL_LOAD   DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP  \
# 742          -0.344706 -0.987968 -0.856204 -0.655528 -1.099226  0.279885
# 1211          1.214288 -0.370990 -0.497520 -1.184018 -1.465608  1.349212
# 1408         -0.540642 -0.344600 -0.372156 -0.623041 -0.926064 -0.148950
# 329          -0.856321 -1.394561 -1.118297  0.244859  0.488650 -1.710888
# 512          -0.552878 -1.374757 -0.790071  0.333817  0.021868 -0.062187
# ...                ...       ...       ...       ...       ...       ...
# 479          -0.666261 -1.224735  2.661142  0.472212  0.630211  1.065727
# 1451          1.038585  0.457145 -0.202629 -0.395438 -0.463636 -0.251075
# 1007         -0.589767 -0.039379 -0.237434  1.358211  1.123953 -0.707839
# 873           0.868310 -0.342771  0.250384  0.227416  0.120661 -0.477558
# 1437         -0.223383 -0.646163  0.738201 -0.903380 -0.882630 -0.247278
#
#        FR_TEMP   GAS_RET  COAL_RET  CARBON_RET
# 742   0.583874 -1.071996 -0.074767    0.798003
# 1211  0.231602  1.480313  0.931562    0.822047
# 1408  0.641235  1.802550  1.140920    0.900434
# 329  -0.951057  0.440121 -0.064550   -0.032756
# 512   1.459745 -0.117977  0.550433    0.781870
# ...        ...       ...       ...         ...
# 479  -1.439105  0.291714  0.568479    0.395742
# 1451 -0.387127 -0.411589  1.774694    1.038661
# 1007 -0.308232  0.017778  0.072168   -0.160792
# 873   0.223629 -0.103642 -0.633007    0.214805
# 1437  0.755489  0.758698  0.078518    0.192945
#
# [851 rows x 35 columns]

# %%
de
# Out:
#        ID  DAY_ID COUNTRY  DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  \
# 1468  111       2      DE       -0.068972       -0.667390       -1.102015
# 680   800       3      DE       -0.134670       -0.834564       -1.051716
# 991   831       5      DE       -0.297850       -0.470371        0.144615
# 1356  779       7      DE        0.057599       -0.625625        0.002239
# 713   841       8      DE       -0.282744       -0.700027        1.309253
# ...   ...     ...     ...             ...             ...             ...
# 168   282    1202      DE       -1.182561       -1.259840       -1.201004
# 1136  505    1207      DE        1.002463        0.516789        0.651648
# 577   823    1208      DE        0.046568       -0.709011        0.427976
# 986   771    1212      DE       -0.046100       -0.520506       -0.270515
# 1465  472    1213      DE        1.407027        1.313254       -0.456126
#
#       FR_DE_EXCHANGE  DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  ...  \
# 1468        1.102015      -1.080403       0.256736       1.080403  ...
# 680         1.051716      -1.881881      -0.612133       1.881881  ...
# 991        -0.144615      -1.208286      -1.811403       1.208286  ...
# 1356       -0.002239      -0.676226      -0.745182       0.676226  ...
# 713        -1.309253       0.248085      -2.226840      -0.248085  ...
# ...              ...            ...            ...            ...  ...
# 168         1.201004      -1.616737       0.619501       1.616737  ...
# 1136       -0.651648       0.728817      -0.820640      -0.728817  ...
# 577        -0.427976      -0.578391      -1.678101       0.578391  ...
# 986         0.270515      -0.137917      -0.789824       0.137917  ...
# 1465        0.456126       0.333142      -0.069222      -0.333142  ...
#
#       FR_RESIDUAL_LOAD   DE_RAIN   FR_RAIN   DE_WIND   FR_WIND   DE_TEMP  \
# 1468         -0.540642 -0.344600 -0.372156 -0.623041 -0.926064 -0.148950
# 680          -0.856321 -1.394561 -1.118297  0.244859  0.488650 -1.710888
# 991          -0.552878 -1.374757 -0.790071  0.333817  0.021868 -0.062187
# 1356         -0.806379 -0.531862 -0.663419  0.098940  1.367421 -0.812164
# 713          -0.791016  1.522720 -0.307449  1.690497  1.584210 -0.441943
# ...                ...       ...       ...       ...       ...       ...
# 168          -1.359708 -0.085663 -0.997403 -0.595651 -0.777719  0.039450
# 1136          0.236243       NaN       NaN       NaN       NaN       NaN
# 577          -0.666261 -1.224735  2.661142  0.472212  0.630211  1.065727
# 986          -0.589767 -0.039379 -0.237434  1.358211  1.123953 -0.707839
# 1465          0.868310       NaN       NaN       NaN       NaN       NaN
#
#        FR_TEMP   GAS_RET  COAL_RET  CARBON_RET
# 1468  0.641235  1.802550  1.140920    0.900434
# 680  -0.951057  0.440121 -0.064550   -0.032756
# 991   1.459745 -0.117977  0.550433    0.781870
# 1356  0.954384 -0.379980  0.518459   -0.034642
# 713  -0.382423  1.557325  0.146634    2.329924
# ...        ...       ...       ...         ...
# 168   1.411276  0.184767  0.257420    0.507079
# 1136       NaN  0.099209  1.750872    0.646905
# 577  -1.439105  0.291714  0.568479    0.395742
# 986  -0.308232  0.017778  0.072168   -0.160792
# 1465       NaN -0.103642 -0.633007    0.214805
#
# [643 rows x 35 columns]

# %%
X_filled = fill_missing_with_average(X)

# %%
X_coor = X_filled.drop(['ID', 'DAY_ID', 'COUNTRY'], axis = 1)
X_coor
# Out:
#       DE_CONSUMPTION  FR_CONSUMPTION  DE_FR_EXCHANGE  FR_DE_EXCHANGE  \
# 742         0.048418       -0.465067       -0.079296        0.079296
# 1211        0.966997        1.222131        0.331356       -0.331356
# 1408       -0.068972       -0.667390       -1.102015        1.102015
# 1468       -0.068972       -0.667390       -1.102015        1.102015
# 329        -0.134670       -0.834564       -1.051716        1.051716
# ...              ...             ...             ...             ...
# 1007       -0.046100       -0.520506       -0.270515        0.270515
# 986        -0.046100       -0.520506       -0.270515        0.270515
# 1465        1.407027        1.313254       -0.456126        0.456126
# 873         1.407027        1.313254       -0.456126        0.456126
# 1437        0.544810       -0.378158       -0.065993        0.065993
#
#       DE_NET_EXPORT  FR_NET_EXPORT  DE_NET_IMPORT  FR_NET_IMPORT    DE_GAS  \
# 742        0.405549       0.650577      -0.405549      -0.650577  0.592572
# 1211       0.405549       0.778627      -0.405549      -0.778627  1.111008
# 1408      -1.080403       0.256736       1.080403      -0.256736  1.228079
# 1468      -1.080403       0.256736       1.080403      -0.256736  1.228079
# 329       -1.881881      -0.612133       1.881881       0.612133  1.588542
# ...             ...            ...            ...            ...       ...
# 1007      -0.137917      -0.789824       0.137917       0.789824  0.231723
# 986       -0.137917      -0.789824       0.137917       0.789824  0.231723
# 1465       0.333142      -0.069222      -0.333142       0.069222  1.781433
# 873        0.333142      -0.069222      -0.333142       0.069222  1.781433
# 1437       0.333142       0.257829      -0.333142      -0.257829  0.233317
#
#         FR_GAS  ...  FR_RESIDUAL_LOAD   DE_RAIN   FR_RAIN   DE_WIND   FR_WIND  \
# 742  -0.261565  ...         -0.344706 -0.987968 -0.856204 -0.655528 -1.099226
# 1211  1.991028  ...          1.214288 -0.370990 -0.497520 -1.184018 -1.465608
# 1408  0.458302  ...         -0.540642 -0.344600 -0.372156 -0.623041 -0.926064
# 1468  0.458302  ...         -0.540642 -0.344600 -0.372156 -0.623041 -0.926064
# 329   0.069297  ...         -0.856321 -1.394561 -1.118297  0.244859  0.488650
# ...        ...  ...               ...       ...       ...       ...       ...
# 1007  0.625656  ...         -0.589767 -0.039379 -0.237434  1.358211  1.123953
# 986   0.625656  ...         -0.589767 -0.039379 -0.237434  1.358211  1.123953
# 1465  1.549682  ...          0.868310 -0.342771  0.250384  0.227416  0.120661
# 873   1.549682  ...          0.868310 -0.494467  0.494292 -0.337982 -0.380984
# 1437 -0.014042  ...         -0.223383 -0.646163  0.738201 -0.903380 -0.882630
#
#        DE_TEMP   FR_TEMP   GAS_RET  COAL_RET  CARBON_RET
# 742   0.279885  0.583874 -1.071996 -0.074767    0.798003
# 1211  1.349212  0.231602  1.480313  0.931562    0.822047
# 1408 -0.148950  0.641235  1.802550  1.140920    0.900434
# 1468 -0.148950  0.641235  1.802550  1.140920    0.900434
# 329  -1.710888 -0.951057  0.440121 -0.064550   -0.032756
# ...        ...       ...       ...       ...         ...
# 1007 -0.707839 -0.308232  0.017778  0.072168   -0.160792
# 986  -0.707839 -0.308232  0.017778  0.072168   -0.160792
# 1465 -0.477558  0.223629 -0.103642 -0.633007    0.214805
# 873  -0.362418  0.489559 -0.103642 -0.633007    0.214805
# 1437 -0.247278  0.755489  0.758698  0.078518    0.192945
#
# [1494 rows x 32 columns]

# %%
import seaborn as sns

correlation_matrix = X_coor.corr()

# Plotting the correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.savefig('images/correlation_matrix.png')
plt.show()

# %%
# Set the threshold for explained variance
variance_threshold = 0.95

# Step 1: Normalize the data
scaler = StandardScaler()
X_normalized = scaler.fit_transform(X_coor)

# Step 2: Apply PCA
pca = PCA()
X_pca = pca.fit_transform(X_normalized)

explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance_ratio = np.cumsum(explained_variance_ratio)

# Identify the index where cumulative variance first surpasses the threshold
num_components_threshold = np.argmax(cumulative_variance_ratio >= variance_threshold) + 1

# Plot the explained variance ratio (Elbow Plot) with a line indicating the threshold
plt.figure(figsize=(12, 6))
plt.plot(range(1, len(explained_variance_ratio) + 1), cumulative_variance_ratio, marker='o', linestyle='-', color='b')
plt.axvline(x=num_components_threshold, color='r', linestyle='--', label=f'Threshold ({variance_threshold*100:.2f}%)')
plt.title('Explained Variance Ratio - Elbow Plot')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.legend()
plt.savefig('images/PCA_elbow.png')
plt.show()

# %%
num_components_threshold
# Out:
# 18

# %%
# Assuming X_pca is a DataFrame with principal components
X_pca = pd.DataFrame(X_pca)
# Keep only the first 18 principal components
X_pca = X_pca.iloc[:, :18]
X_pca
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.349449 -1.672174 -0.339356 -1.995607  0.106948 -1.603525  1.956397
# 1     3.086950 -2.545378  0.775685 -0.811237 -1.575662 -2.271414  0.398823
# 2    -2.147439 -2.031974 -0.023908  0.527266 -0.891402 -1.552983 -0.593549
# 3    -2.147439 -2.031974 -0.023908  0.527266 -0.891402 -1.552983 -0.593549
# 4    -3.910903 -1.361944 -2.982788  0.686778  1.771020  0.497867 -0.989107
# ...        ...       ...       ...       ...       ...       ...       ...
# 1489 -1.741782  2.003373 -1.881857  0.374429  0.826020  0.306216  0.092674
# 1490 -1.741782  2.003373 -1.881857  0.374429  0.826020  0.306216  0.092674
# 1491  3.506382 -0.981513  1.287179  0.372944 -0.222329  1.095080 -0.913652
# 1492  3.480661 -1.257486  1.383272 -0.057683 -0.556681  0.950111 -1.045357
# 1493  0.123398 -2.057962 -0.674945 -1.014859 -0.140604 -1.837997  2.191425
#
#             7         8         9         10        11        12        13  \
# 0     0.018014 -0.118627 -0.113256 -0.717055  0.257143  1.101532 -0.618825
# 1    -0.534087 -0.401293 -0.316021  0.490932 -0.149166 -1.150078 -1.337468
# 2     0.158379 -0.762241 -0.283111  0.379949  0.454306 -0.493115  0.851702
# 3     0.158379 -0.762241 -0.283111  0.379949  0.454306 -0.493115  0.851702
# 4    -1.328108  0.086704 -0.126540  0.451558  0.700483  0.011493  0.172654
# ...        ...       ...       ...       ...       ...       ...       ...
# 1489 -0.441509  0.286975 -0.562739  0.285294 -0.643979 -0.471630 -0.610926
# 1490 -0.441509  0.286975 -0.562739  0.285294 -0.643979 -0.471630 -0.610926
# 1491 -0.676124  0.606743 -0.122255  1.146716  0.341081  0.239120 -0.877720
# 1492 -0.436738  0.776624 -0.230912  1.165866  0.291728  0.293646 -0.717161
# 1493  0.642360  1.051508  0.720804 -0.807748  0.514453 -0.072294  0.392010
#
#             14        15        16        17
# 0     0.479906  0.725032 -0.696957 -0.446415
# 1    -1.266542 -0.079918  0.136025  0.610440
# 2    -0.071916 -0.823515 -0.159384  0.041934
# 3    -0.071916 -0.823515 -0.159384  0.041934
# 4    -0.579836  0.202268 -0.300386  0.055008
# ...        ...       ...       ...       ...
# 1489 -0.950911  0.110082 -0.576424 -0.157133
# 1490 -0.950911  0.110082 -0.576424 -0.157133
# 1491  0.082302  0.572968 -1.018767 -0.438186
# 1492  0.038305  0.752900 -1.035170 -0.147256
# 1493  0.747795  1.156115 -0.946340  0.045124
#
# [1494 rows x 18 columns]

# %%
# Plotting the correlation heatmap for the reconstructed features
correlation_matrix_reconstructed = X_pca.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix_reconstructed, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix for Reconstructed Features')
plt.savefig('images/correlation_matrix_PCA.png')
plt.show()
